# %% [markdown]
# # Housing price prediction in Bogota, Colombia
# [Author: Elias Buitrago Bolivar](https://github.com/ebuitrago?tab=repositories)
#
# This jupyter notebook depicts a python based web scraping  algorithm to obtain real estate data from the portal fincaraiz.com.co. The code presented here is functional and was tested by scraping real estate data of used apartments sales from Bogota, Colombia. It is recommended to run the notebook locally in Ananconda, as there is a bug when running it on platforms such as google colab.
#
# _Updated: February 25th, 2023_

# %% [markdown]
# ## Experimental design

# %% [markdown]
# ### Web Scraping real estate data
# This section explains the web scraping process applied to the fincaraiz.com.co web page.

# %% [markdown]
# #### Import required libreries

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import pandas as pd

# %%
#Function to get 'href' from each article item
def gethref(soup):

    links = []

    for article in soup.find_all(attrs={"class": "listingCard"}):
        
        url = article.find('a', href=True)

        if url:
            link = url['href']
            links.append(link)

    print("Href obtained: ", len(links))

    return links

# %%
def varsfromscrap(soup, cols):

    features = []
    aux_dict = {}

    for i in range(0, len(soup), 3):

        if soup[i + 2].text == "¡Pregúntale!":       
            val = "NaN"
        else:
            val = soup[i + 2].text

        aux_dict[soup[i].text[2:]] = val

    features = [aux_dict.get(col, "NaN") for col in cols]

    return features

# %%
# Version 1.0
def housing_features(soup, cols):

    #Obtaining whole info from the html section that stores main housing variables
    s = soup.find('div',{'class':'technical-sheet'}).find_all(class_='ant-col')
    #print(s)

    #Extract first 10 features from soup
    feautures = varsfromscrap(s, cols)

    # Adding Price
    price = soup.find('span',{'class':'price'}).text
    feautures[-1] = price

    return feautures

# %%
#Function to call housing_features routine on each href
def scrapper(id_inmueble, cols):

    #Initialize and execute Selenium
    op = webdriver.ChromeOptions()
    op.add_argument('headless')
    browser = webdriver.Chrome(options=op)
    url_inm = 'https://www.fincaraiz.com.co' + id_inmueble + '/'
    print(url_inm)
    browser.get(url_inm)
    browser.implicitly_wait(10)
    html=browser.page_source

    #Obtaining the html from the web page after applying Selenium
    soup=bs(html,'lxml')

    #Create a list to store info obtained from one particular property
    features = []

    #Applying function to obtain variables defined from one particular property
    features = housing_features(soup, cols)

    #Close the web browser tab
    browser.close()

    #Close the web browser
    browser.quit()

    return(features)

# %% [markdown]
# ## Selenium

# %%
#Selenium+BS
pag = 1
url = f'https://www.fincaraiz.com.co/venta/casas-y-apartamentos-y-apartaestudios/medellin/antioquia/usados?pagina={pag}'

op = webdriver.ChromeOptions()
op.add_argument('headless')
browser = webdriver.Chrome(options=op)

print(url)
browser.get(url)
browser.implicitly_wait(10)
html = browser.page_source
soup = bs(html,'lxml')
# Out:
# https://www.fincaraiz.com.co/venta/casas-y-apartamentos-y-apartaestudios/medellin/antioquia/usados?pagina=1

# %%
#Get href
links = gethref(soup)
# Out:
# Href obtained:  21

# %%
#Scraping
cols = ["Estrato", "Tipo de Inmueble", "Estado", "Baños", "Área Construida", "Área Privada", "Antigüedad", "Habitaciones",
        "Parqueaderos", "Administración", "Precio"]

data = pd.DataFrame(columns=cols)

p = []
#Scraping a los inmuebles filtrados
for i, link in enumerate(links):

    print('Scrapping', i, '/', len(links), '...')
    p.append(scrapper(link, cols))
    print(p[i])

    #append list to DataFrame
    data.loc[len(data)] = p[i]
# Out:
# Scrapping 0 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191702331/
# ['6', 'Apartamento', 'NaN', '5', '234.00  m2', '234.00  m2', '16 a 30 años', '3', '3', '1,110,000.00', '$ 2.129.000.000']
# Scrapping 1 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191466600/
# ['5', 'Apartamento', 'NaN', '4', '166.00  m2', '166.00  m2', '9 a 15 años', '3', '1', 'NaN', '$ 850.000.000']
# Scrapping 2 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191266208/
# ['4', 'Apartamento', 'NaN', '2', '60.32  m2', '60.32  m2', '1 a 8 años', '3', '1', '250,000.00', '$ 339.000.000']
# Scrapping 3 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191415776/
# ['5', 'Apartamento', 'NaN', '2', '83.00  m2', '83.00  m2', 'NaN', '2', 'NaN', '660,000.00', '$ 540.000.000']
# Scrapping 4 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191435403/
# ['5', 'Apartamento', 'NaN', '3', '166.00  m2', '166.00  m2', 'más de 30 años', '3', '2', '1,075,000.00', '$ 990.000.000']
# Scrapping 5 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191435443/
# ['6', 'Apartamento', 'NaN', '3', '132.00  m2', '132.00  m2', '9 a 15 años', '3', '2', '912,300.00', '$ 1.300.000.000']
# Scrapping 6 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191435538/
# ['5', 'Apartamento', 'NaN', '3', '120.00  m2', '120.00  m2', '1 a 8 años', '3', '1', 'NaN', '$ 900.000.000']
# Scrapping 7 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191716974/
# ['3', 'Apartamento', 'NaN', '2', '60.00  m2', '60.00  m2', 'más de 30 años', '3', '1', '127,000.00', '$ 350.000.000']
# Scrapping 8 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191747633/
# ['5', 'Apartamento', 'Buen estado', 'NaN', '82.00  m2', '82.00  m2', 'más de 30 años', '3', '1', '356,000.00', '$ 438.000.000']
# Scrapping 9 / 21 ...
# https://www.fincaraiz.com.co/casa-en-venta/191422978/
# ['4', 'Casa', 'NaN', '6', '343.00  m2', '261.00  m2', 'menor a 1 año', '6', '2', 'NaN', '$ 1.500.000.000']
# Scrapping 10 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191762023/
# ['5', 'Apartamento', 'NaN', '3', '136.00  m2', '136.00  m2', 'NaN', '3', '2', '308,000.00', '$ 650.000.000']
# Scrapping 11 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191502887/
# ['3', 'Apartamento', 'NaN', '2', '93.00  m2', '93.00  m2', 'NaN', '3', 'NaN', 'NaN', '$ 260.000.000']
# Scrapping 12 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191737492/
# ['5', 'Apartamento', 'NaN', '3', '138.00  m2', '138.00  m2', '16 a 30 años', '3', '1', '519,000.00', '$ 760.000.000']
# Scrapping 13 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191444581/
# ['3', 'Apartamento', 'NaN', '2', '54.00  m2', '54.00  m2', '1 a 8 años', '3', '1', '150,000.00', '$ 240.000.000']
# Scrapping 14 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/10619175/
# ['5', 'Apartamento', 'NaN', '3', '110.00  m2', '110.00  m2', 'NaN', '4', '2', '622,000.00', '$ 800.000.000']
# Scrapping 15 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191435782/
# ['5', 'Apartamento', 'NaN', '3', '161.00  m2', '161.00  m2', '1 a 8 años', '3', '2', '1,023,000.00', '$ 1.290.000.000']
# Scrapping 16 / 21 ...
# https://www.fincaraiz.com.co/casa-en-venta/191057352/
# ['4', 'Casa', 'NaN', '2', '135.94  m2', 'NaN', 'NaN', '4', '2', 'NaN', '$ 650.000.000']
# Scrapping 17 / 21 ...
# https://www.fincaraiz.com.co/casa-en-venta/191435471/
# ['5', 'Casa', 'NaN', '3', '162.00  m2', '162.00  m2', 'más de 30 años', '6', 'NaN', 'NaN', '$ 1.350.000.000']
# Scrapping 18 / 21 ...
# https://www.fincaraiz.com.co/casa-en-venta/191547952/
# ['3', 'Casa', 'NaN', '1', '70.00  m2', '70.00  m2', '9 a 15 años', '3', 'NaN', 'NaN', '$ 233.000.000']
# Scrapping 19 / 21 ...
# https://www.fincaraiz.com.co/apartamento-en-venta/191422513/
# ['5', 'Apartamento', 'NaN', '2', '75.00  m2', '75.00  m2', '1 a 8 años', '1', '1', '675,000.00', '$ 700.000.000']
# Scrapping 20 / 21 ...
# https://www.fincaraiz.com.co/casa-en-venta/191785494/
# ['4', 'Casa', 'NaN', '3', '220.00  m2', 'NaN', '16 a 30 años', '4', '2', 'NaN', '$ 675.000.000']

# %%
display(data)
# Out:
#    Estrato Tipo de Inmueble       Estado Baños Área Construida Área Privada  \
# 0        6      Apartamento          NaN     5      234.00  m2   234.00  m2
# 1        5      Apartamento          NaN     4      166.00  m2   166.00  m2
# 2        4      Apartamento          NaN     2       60.32  m2    60.32  m2
# 3        5      Apartamento          NaN     2       83.00  m2    83.00  m2
# 4        5      Apartamento          NaN     3      166.00  m2   166.00  m2
# 5        6      Apartamento          NaN     3      132.00  m2   132.00  m2
# 6        5      Apartamento          NaN     3      120.00  m2   120.00  m2
# 7        3      Apartamento          NaN     2       60.00  m2    60.00  m2
# 8        5      Apartamento  Buen estado   NaN       82.00  m2    82.00  m2
# 9        4             Casa          NaN     6      343.00  m2   261.00  m2
# 10       5      Apartamento          NaN     3      136.00  m2   136.00  m2
# 11       3      Apartamento          NaN     2       93.00  m2    93.00  m2
# 12       5      Apartamento          NaN     3      138.00  m2   138.00  m2
# 13       3      Apartamento          NaN     2       54.00  m2    54.00  m2
# 14       5      Apartamento          NaN     3      110.00  m2   110.00  m2
# 15       5      Apartamento          NaN     3      161.00  m2   161.00  m2
# 16       4             Casa          NaN     2      135.94  m2          NaN
# 17       5             Casa          NaN     3      162.00  m2   162.00  m2
# 18       3             Casa          NaN     1       70.00  m2    70.00  m2
# 19       5      Apartamento          NaN     2       75.00  m2    75.00  m2
# 20       4             Casa          NaN     3      220.00  m2          NaN
#
#         Antigüedad Habitaciones Parqueaderos Administración           Precio
# 0     16 a 30 años            3            3   1,110,000.00  $ 2.129.000.000
# 1      9 a 15 años            3            1            NaN    $ 850.000.000
# 2       1 a 8 años            3            1     250,000.00    $ 339.000.000
# 3              NaN            2          NaN     660,000.00    $ 540.000.000
# 4   más de 30 años            3            2   1,075,000.00    $ 990.000.000
# 5      9 a 15 años            3            2     912,300.00  $ 1.300.000.000
# 6       1 a 8 años            3            1            NaN    $ 900.000.000
# 7   más de 30 años            3            1     127,000.00    $ 350.000.000
# 8   más de 30 años            3            1     356,000.00    $ 438.000.000
# 9    menor a 1 año            6            2            NaN  $ 1.500.000.000
# 10             NaN            3            2     308,000.00    $ 650.000.000
# 11             NaN            3          NaN            NaN    $ 260.000.000
# 12    16 a 30 años            3            1     519,000.00    $ 760.000.000
# 13      1 a 8 años            3            1     150,000.00    $ 240.000.000
# 14             NaN            4            2     622,000.00    $ 800.000.000
# 15      1 a 8 años            3            2   1,023,000.00  $ 1.290.000.000
# 16             NaN            4            2            NaN    $ 650.000.000
# 17  más de 30 años            6          NaN            NaN  $ 1.350.000.000
# 18     9 a 15 años            3          NaN            NaN    $ 233.000.000
# 19      1 a 8 años            1            1     675,000.00    $ 700.000.000
# 20    16 a 30 años            4            2            NaN    $ 675.000.000

# %% [markdown]
# #### Initialize and execute Selenium + BeautifulSoap

# %%
# data.to_csv('used_properties_medellin_2024.csv', encoding='utf-8', index=False)
